# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
spotify_data= Path("/Users/amanda/Desktop/Project_1/spotify-2023.csv")

# %%
spotify_data_df = pd.read_csv(spotify_data, encoding='latin-1')

# %%
spotify_data_df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                147  141381703                  43  ...  125   B  Major
# 1                 48  133716286                  48  ...   92  C#  Major
# 2                113  140003974                  94  ...  138   F  Major
# 3                100  800840817                 116  ...  170   A  Major
# 4                 50  303236322                  84  ...  144   A  Minor
#
#   danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0             80         89       83             31                   0
# 1             71         61       74              7                   0
# 2             51         32       53             17                   0
# 3             55         58       72             11                   0
# 4             65         23       80             14                  63
#
#    liveness_%  speechiness_%
# 0           8              4
# 1          10              4
# 2          31              6
# 3          11             15
# 4          11              6
#
# [5 rows x 24 columns]

# %%
genre_data = Path("/Users/amanda/Desktop/Project_1/all_data_genre.csv")

# %%
genre_df = pd.read_csv(genre_data, encoding='latin-1')
genre_df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 812                         My Mind & Me        Selena Gomez             1
# 813            Bigger Than The Whole Sky        Taylor Swift             1
# 814                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 815                        En La De Ella  Feid, Sech, Jhayco             3
# 816                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 812           2022              11             3                   953
# 813           2022              10            21                  1180
# 814           2022              11             3                   573
# 815           2022              10            20                  1320
# 816           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...   mode  \
# 0                  147  141381703                  43  ...  Major
# 1                   48  133716286                  48  ...  Major
# 2                  113  140003974                  94  ...  Major
# 3                  100  800840817                 116  ...  Major
# 4                   50  303236322                  84  ...  Minor
# ..                 ...        ...                 ...  ...    ...
# 812                  0   91473363                  61  ...  Major
# 813                  0  121871870                   4  ...  Major
# 814                  0   73513683                   2  ...  Major
# 815                  0  133895612                  29  ...  Major
# 816                  2   96007391                  27  ...  Minor
#
#     danceability_%  valence_% energy_%  acousticness_% instrumentalness_%  \
# 0               80         89       83              31                  0
# 1               71         61       74               7                  0
# 2               51         32       53              17                  0
# 3               55         58       72              11                  0
# 4               65         23       80              14                 63
# ..             ...        ...      ...             ...                ...
# 812             60         24       39              57                  0
# 813             42          7       24              83                  1
# 814             80         81       67               4                  0
# 815             82         67       77               8                  0
# 816             61         32       67              15                  0
#
#     liveness_%  speechiness_%  Deezer Album ID  Deezer Genre
# 0            8              4        463574485   Asian Music
# 1           10              4        410083687   Rap/Hip Hop
# 2           31              6        484372295           Pop
# 3           11             15        108447472           Pop
# 4           11              6        442984025   Latin Music
# ..         ...            ...              ...           ...
# 812          8              3        372408897           Pop
# 813         12              6        368506677           Pop
# 814          8              6        382808197           Pop
# 815         12              5        367159307   Rap/Hip Hop
# 816         11              5        373539777   Films/Games
#
# [817 rows x 26 columns]

# %%
sp_df = spotify_data_df.dropna()
sp_df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                  147  141381703                  43  ...  125   B  Major
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0               80         89       83             31                   0
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [817 rows x 24 columns]

# %%
merged_data = pd.merge(sp_df, genre_df, how ="left", on = "track_name")
merged_data
# Out:
#                               track_name    artist(s)_name_x  artist_count_x  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook               2
# 1                                   LALA         Myke Towers               1
# 2                                vampire      Olivia Rodrigo               1
# 3                           Cruel Summer        Taylor Swift               1
# 4                         WHERE SHE GOES           Bad Bunny               1
# ..                                   ...                 ...             ...
# 824                         My Mind & Me        Selena Gomez               1
# 825            Bigger Than The Whole Sky        Taylor Swift               1
# 826                 A Veces (feat. Feid)  Feid, Paulo Londra               2
# 827                        En La De Ella  Feid, Sech, Jhayco               3
# 828                                Alone           Burna Boy               1
#
#      released_year_x  released_month_x  released_day_x  \
# 0               2023                 7              14
# 1               2023                 3              23
# 2               2023                 6              30
# 3               2019                 8              23
# 4               2023                 5              18
# ..               ...               ...             ...
# 824             2022                11               3
# 825             2022                10              21
# 826             2022                11               3
# 827             2022                10              20
# 828             2022                11               4
#
#      in_spotify_playlists_x  in_spotify_charts_x  streams_x  \
# 0                       553                  147  141381703
# 1                      1474                   48  133716286
# 2                      1397                  113  140003974
# 3                      7858                  100  800840817
# 4                      3133                   50  303236322
# ..                      ...                  ...        ...
# 824                     953                    0   91473363
# 825                    1180                    0  121871870
# 826                     573                    0   73513683
# 827                    1320                    0  133895612
# 828                     782                    2   96007391
#
#      in_apple_playlists_x  ...  mode_y danceability_%_y  valence_%_y  \
# 0                      43  ...   Major               80           89
# 1                      48  ...   Major               71           61
# 2                      94  ...   Major               51           32
# 3                     116  ...   Major               55           58
# 4                      84  ...   Minor               65           23
# ..                    ...  ...     ...              ...          ...
# 824                    61  ...   Major               60           24
# 825                     4  ...   Major               42            7
# 826                     2  ...   Major               80           81
# 827                    29  ...   Major               82           67
# 828                    27  ...   Minor               61           32
#
#     energy_%_y  acousticness_%_y instrumentalness_%_y liveness_%_y  \
# 0           83                31                    0            8
# 1           74                 7                    0           10
# 2           53                17                    0           31
# 3           72                11                    0           11
# 4           80                14                   63           11
# ..         ...               ...                  ...          ...
# 824         39                57                    0            8
# 825         24                83                    1           12
# 826         67                 4                    0            8
# 827         77                 8                    0           12
# 828         67                15                    0           11
#
#      speechiness_%_y  Deezer Album ID  Deezer Genre
# 0                  4        463574485   Asian Music
# 1                  4        410083687   Rap/Hip Hop
# 2                  6        484372295           Pop
# 3                 15        108447472           Pop
# 4                  6        442984025   Latin Music
# ..               ...              ...           ...
# 824                3        372408897           Pop
# 825                6        368506677           Pop
# 826                6        382808197           Pop
# 827                5        367159307   Rap/Hip Hop
# 828                5        373539777   Films/Games
#
# [829 rows x 49 columns]

# %%
reduced_data = merged_data[["track_name", "artist(s)_name_x", "in_spotify_charts_x", "in_apple_charts_x", "in_deezer_charts_x", "key_y", "bpm_y", "Deezer Genre"]]
reduced_data
# Out:
#                               track_name    artist(s)_name_x  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook
# 1                                   LALA         Myke Towers
# 2                                vampire      Olivia Rodrigo
# 3                           Cruel Summer        Taylor Swift
# 4                         WHERE SHE GOES           Bad Bunny
# ..                                   ...                 ...
# 824                         My Mind & Me        Selena Gomez
# 825            Bigger Than The Whole Sky        Taylor Swift
# 826                 A Veces (feat. Feid)  Feid, Paulo Londra
# 827                        En La De Ella  Feid, Sech, Jhayco
# 828                                Alone           Burna Boy
#
#      in_spotify_charts_x  in_apple_charts_x  in_deezer_charts_x key_y  bpm_y  \
# 0                    147                263                  10     B    125
# 1                     48                126                  14    C#     92
# 2                    113                207                  14     F    138
# 3                    100                207                  12     A    170
# 4                     50                133                  15     A    144
# ..                   ...                ...                 ...   ...    ...
# 824                    0                 13                   1     A    144
# 825                    0                  0                   0    F#    166
# 826                    0                  0                   0    C#     92
# 827                    0                 26                   0    C#     97
# 828                    2                 18                   1     E     90
#
#     Deezer Genre
# 0    Asian Music
# 1    Rap/Hip Hop
# 2            Pop
# 3            Pop
# 4    Latin Music
# ..           ...
# 824          Pop
# 825          Pop
# 826          Pop
# 827  Rap/Hip Hop
# 828  Films/Games
#
# [829 rows x 8 columns]

# %%
reduced_data.dropna()
# Out:
#                               track_name    artist(s)_name_x  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook
# 1                                   LALA         Myke Towers
# 2                                vampire      Olivia Rodrigo
# 3                           Cruel Summer        Taylor Swift
# 4                         WHERE SHE GOES           Bad Bunny
# ..                                   ...                 ...
# 824                         My Mind & Me        Selena Gomez
# 825            Bigger Than The Whole Sky        Taylor Swift
# 826                 A Veces (feat. Feid)  Feid, Paulo Londra
# 827                        En La De Ella  Feid, Sech, Jhayco
# 828                                Alone           Burna Boy
#
#      in_spotify_charts_x  in_apple_charts_x  in_deezer_charts_x key_y  bpm_y  \
# 0                    147                263                  10     B    125
# 1                     48                126                  14    C#     92
# 2                    113                207                  14     F    138
# 3                    100                207                  12     A    170
# 4                     50                133                  15     A    144
# ..                   ...                ...                 ...   ...    ...
# 824                    0                 13                   1     A    144
# 825                    0                  0                   0    F#    166
# 826                    0                  0                   0    C#     92
# 827                    0                 26                   0    C#     97
# 828                    2                 18                   1     E     90
#
#     Deezer Genre
# 0    Asian Music
# 1    Rap/Hip Hop
# 2            Pop
# 3            Pop
# 4    Latin Music
# ..           ...
# 824          Pop
# 825          Pop
# 826          Pop
# 827  Rap/Hip Hop
# 828  Films/Games
#
# [711 rows x 8 columns]

# %%
track_name = reduced_data["track_name"]
track_name
artist_name = reduced_data["artist(s)_name_x"]
key = reduced_data["key_y"]
bpm = reduced_data["bpm_y"]
genre = reduced_data["Deezer Genre"]

# %%
spotify_chart = pd.to_numeric(reduced_data["in_spotify_charts_x"])
spotify_chart
apple_chart= pd.to_numeric(reduced_data["in_apple_charts_x"])
apple_chart
deezer_chart = pd.to_numeric(reduced_data["in_deezer_charts_x"])
deezer_chart
# Out:
# 0      10
# 1      14
# 2      14
# 3      12
# 4      15
#        ..
# 824     1
# 825     0
# 826     0
# 827     0
# 828     1
# Name: in_deezer_charts_x, Length: 829, dtype: int64

# %%
df_2 = pd.DataFrame()

df_2["Track Name"] = track_name
df_2["Artist(s) Name"] = artist_name
df_2["Spotify Chart Ranking"] = spotify_chart
df_2["Apple Chart Ranking"] = apple_chart
df_2["Deezer Chart Ranking"] = deezer_chart
df_2["Key"] = key
df_2["BPM"] = bpm
df_2["Genre"] = genre

df_2
# Out:
#                               Track Name      Artist(s) Name  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook
# 1                                   LALA         Myke Towers
# 2                                vampire      Olivia Rodrigo
# 3                           Cruel Summer        Taylor Swift
# 4                         WHERE SHE GOES           Bad Bunny
# ..                                   ...                 ...
# 824                         My Mind & Me        Selena Gomez
# 825            Bigger Than The Whole Sky        Taylor Swift
# 826                 A Veces (feat. Feid)  Feid, Paulo Londra
# 827                        En La De Ella  Feid, Sech, Jhayco
# 828                                Alone           Burna Boy
#
#      Spotify Chart Ranking  Apple Chart Ranking  Deezer Chart Ranking Key  \
# 0                      147                  263                    10   B
# 1                       48                  126                    14  C#
# 2                      113                  207                    14   F
# 3                      100                  207                    12   A
# 4                       50                  133                    15   A
# ..                     ...                  ...                   ...  ..
# 824                      0                   13                     1   A
# 825                      0                    0                     0  F#
# 826                      0                    0                     0  C#
# 827                      0                   26                     0  C#
# 828                      2                   18                     1   E
#
#      BPM        Genre
# 0    125  Asian Music
# 1     92  Rap/Hip Hop
# 2    138          Pop
# 3    170          Pop
# 4    144  Latin Music
# ..   ...          ...
# 824  144          Pop
# 825  166          Pop
# 826   92          Pop
# 827   97  Rap/Hip Hop
# 828   90  Films/Games
#
# [829 rows x 8 columns]

# %%
df_3 = df_2.loc[df_2["Spotify Chart Ranking"] != 0]
df_3
# Out:
#                               Track Name                      Artist(s) Name  \
# 0    Seven (feat. Latto) (Explicit Ver.)                    Latto, Jung Kook
# 1                                   LALA                         Myke Towers
# 2                                vampire                      Olivia Rodrigo
# 3                           Cruel Summer                        Taylor Swift
# 4                         WHERE SHE GOES                           Bad Bunny
# ..                                   ...                                 ...
# 807            Bamba (feat. Aitch & BIA)                Luciano, Aitch, Bï¿½
# 808                  Casei Com a Putaria  MC Ryan SP, Love Funk, Mc Paiva ZS
# 816                          Spin Bout U                    Drake, 21 Savage
# 820                        The Astronaut                                 Jin
# 828                                Alone                           Burna Boy
#
#      Spotify Chart Ranking  Apple Chart Ranking  Deezer Chart Ranking Key  \
# 0                      147                  263                    10   B
# 1                       48                  126                    14  C#
# 2                      113                  207                    14   F
# 3                      100                  207                    12   A
# 4                       50                  133                    15   A
# ..                     ...                  ...                   ...  ..
# 807                      7                   12                     2  A#
# 808                      4                    0                     0  A#
# 816                      2                   52                     0   G
# 820                      9                  100                     1   F
# 828                      2                   18                     1   E
#
#      BPM            Genre
# 0    125      Asian Music
# 1     92      Rap/Hip Hop
# 2    138              Pop
# 3    170              Pop
# 4    144      Latin Music
# ..   ...              ...
# 807  138              NaN
# 808  161  Brazilian Music
# 816  130      Rap/Hip Hop
# 820  125      Asian Music
# 828   90      Films/Games
#
# [473 rows x 8 columns]

# %%
df_4 = df_3.loc[df_3["Apple Chart Ranking"] != 0]
df_4
# Out:
#                               Track Name        Artist(s) Name  \
# 0    Seven (feat. Latto) (Explicit Ver.)      Latto, Jung Kook
# 1                                   LALA           Myke Towers
# 2                                vampire        Olivia Rodrigo
# 3                           Cruel Summer          Taylor Swift
# 4                         WHERE SHE GOES             Bad Bunny
# ..                                   ...                   ...
# 805                            Typa Girl             BLACKPINK
# 807            Bamba (feat. Aitch & BIA)  Luciano, Aitch, Bï¿½
# 816                          Spin Bout U      Drake, 21 Savage
# 820                        The Astronaut                   Jin
# 828                                Alone             Burna Boy
#
#      Spotify Chart Ranking  Apple Chart Ranking  Deezer Chart Ranking Key  \
# 0                      147                  263                    10   B
# 1                       48                  126                    14  C#
# 2                      113                  207                    14   F
# 3                      100                  207                    12   A
# 4                       50                  133                    15   A
# ..                     ...                  ...                   ...  ..
# 805                     10                  129                     0   G
# 807                      7                   12                     2  A#
# 816                      2                   52                     0   G
# 820                      9                  100                     1   F
# 828                      2                   18                     1   E
#
#      BPM        Genre
# 0    125  Asian Music
# 1     92  Rap/Hip Hop
# 2    138          Pop
# 3    170          Pop
# 4    144  Latin Music
# ..   ...          ...
# 805  132          Pop
# 807  138          NaN
# 816  130  Rap/Hip Hop
# 820  125  Asian Music
# 828   90  Films/Games
#
# [444 rows x 8 columns]

# %%
all_three_df = df_4.loc[df_4["Deezer Chart Ranking"] != 0]
all_three_df
# Out:
#                               Track Name             Artist(s) Name  \
# 0    Seven (feat. Latto) (Explicit Ver.)           Latto, Jung Kook
# 1                                   LALA                Myke Towers
# 2                                vampire             Olivia Rodrigo
# 3                           Cruel Summer               Taylor Swift
# 4                         WHERE SHE GOES                  Bad Bunny
# ..                                   ...                        ...
# 793                           Sin Seï¿½ï  Ovy On The Drums, Quevedo
# 796                        THE LONELIEST                  Mï¿½ï¿½ne
# 807            Bamba (feat. Aitch & BIA)       Luciano, Aitch, Bï¿½
# 820                        The Astronaut                        Jin
# 828                                Alone                  Burna Boy
#
#      Spotify Chart Ranking  Apple Chart Ranking  Deezer Chart Ranking Key  \
# 0                      147                  263                    10   B
# 1                       48                  126                    14  C#
# 2                      113                  207                    14   F
# 3                      100                  207                    12   A
# 4                       50                  133                    15   A
# ..                     ...                  ...                   ...  ..
# 793                      2                   10                     1   B
# 796                      5                   65                     1   D
# 807                      7                   12                     2  A#
# 820                      9                  100                     1   F
# 828                      2                   18                     1   E
#
#      BPM        Genre
# 0    125  Asian Music
# 1     92  Rap/Hip Hop
# 2    138          Pop
# 3    170          Pop
# 4    144  Latin Music
# ..   ...          ...
# 793  118    Classical
# 796  130         Rock
# 807  138          NaN
# 820  125  Asian Music
# 828   90  Films/Games
#
# [277 rows x 8 columns]

# %%
duplicated_songs = all_three_df[all_three_df['Track Name'].duplicated(keep = False)]
duplicated_songs
# Out:
#     Track Name             Artist(s) Name  Spotify Chart Ranking  \
# 292   Miss You  Robin Schulz, Oliver Tree                     10
# 293   Miss You  Robin Schulz, Oliver Tree                     10
#
#      Apple Chart Ranking  Deezer Chart Ranking Key  BPM  Genre
# 292                   16                     3  F#  145  Dance
# 293                   16                     3   A  145  Dance

# %%
final_df = all_three_df.drop_duplicates(subset=['Track Name'])
final_df
# Out:
#                               Track Name             Artist(s) Name  \
# 0    Seven (feat. Latto) (Explicit Ver.)           Latto, Jung Kook
# 1                                   LALA                Myke Towers
# 2                                vampire             Olivia Rodrigo
# 3                           Cruel Summer               Taylor Swift
# 4                         WHERE SHE GOES                  Bad Bunny
# ..                                   ...                        ...
# 793                           Sin Seï¿½ï  Ovy On The Drums, Quevedo
# 796                        THE LONELIEST                  Mï¿½ï¿½ne
# 807            Bamba (feat. Aitch & BIA)       Luciano, Aitch, Bï¿½
# 820                        The Astronaut                        Jin
# 828                                Alone                  Burna Boy
#
#      Spotify Chart Ranking  Apple Chart Ranking  Deezer Chart Ranking Key  \
# 0                      147                  263                    10   B
# 1                       48                  126                    14  C#
# 2                      113                  207                    14   F
# 3                      100                  207                    12   A
# 4                       50                  133                    15   A
# ..                     ...                  ...                   ...  ..
# 793                      2                   10                     1   B
# 796                      5                   65                     1   D
# 807                      7                   12                     2  A#
# 820                      9                  100                     1   F
# 828                      2                   18                     1   E
#
#      BPM        Genre
# 0    125  Asian Music
# 1     92  Rap/Hip Hop
# 2    138          Pop
# 3    170          Pop
# 4    144  Latin Music
# ..   ...          ...
# 793  118    Classical
# 796  130         Rock
# 807  138          NaN
# 820  125  Asian Music
# 828   90  Films/Games
#
# [276 rows x 8 columns]

# %%
key_data = final_df["Key"].value_counts()
key_data

key_data.plot.bar()
plt.title("Number of Songs in each Key")
plt.ylabel("# of Songs")
plt.xticks(rotation=0)
plt.savefig('output_data/key_fig.png')
plt.show()

# %%
# bpm_data = final_df["BPM"].value_counts()
# bpm_data
bins =[49, 69, 89, 109, 129, 149, 169, 189, 209]
group_names = ["50-69", "70-89", "90-109", "110-129", "130-149", "150-169", "170-189", "190-210",]


final_df["BPM Groups"] = pd.cut(final_df["BPM"], bins, labels=group_names)
final_df.head()
#find ranges for BPM and group them

bpm_groups = final_df['BPM Groups'].value_counts()
bpm_groups
# Out:
# /var/folders/hp/2chmjvj91xx59x40ttq2c6q00000gn/T/ipykernel_83702/2525341668.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["BPM Groups"] = pd.cut(final_df["BPM"], bins, labels=group_names)
# BPM Groups
# 90-109     78
# 110-129    68
# 130-149    56
# 170-189    28
# 150-169    24
# 70-89      16
# 190-210     5
# 50-69       1
# Name: count, dtype: int64

# %%
bpm_groups.plot.pie(labels= bpm_groups.index,autopct= "%1.1f%%", pctdistance=.86)
plt.ylabel('')
plt.title("Number of Songs by BPM")
plt.savefig('output_data/bpm_fig.png')
plt.show()

# %%
genre_data = final_df["Genre"].value_counts()
genre_data
# Out:
# Genre
# Pop                     53
# Rap/Hip Hop             47
# Latin Music             27
# Alternative             20
# Traditional Mexicano    14
# Asian Music             12
# R&B                     11
# Reggaeton               10
# Brazilian Music          8
# Rock                     7
# Dance                    6
# Electro                  5
# Country                  4
# African Music            3
# Singer & Songwriter      3
# Classical                2
# Films/Games              2
# Cumbia                   1
# Banda/Grupero            1
# Name: count, dtype: int64

# %%
# genre_data.plot.pie(autopct= "%1.1f%%" ,pctdistance=1.1, labeldistance=1.2)
# plt.legend(bbox_to_anchor=(1.4, 1), loc='upper left')
# plt.show()

genre_data.plot.bar()
plt.ylabel("# of Songs")
plt.xticks(rotation= 90)
plt.title ("Number of Songs per Genre")
plt.savefig('output_data/genre_fig.png')
plt.show()


#format
